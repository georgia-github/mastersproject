# %%
# %matplotlib inline
# %run test_waveform

# %%
# %matplotlib inline
# %run test_template_bank
# Out:
# Number of templates is 39494
# 39494
# 23642

# %%
# %matplotlib inline
# %run test_matched_filter
