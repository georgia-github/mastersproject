# %%
# %matplotlib inline
# %run graphcompile

# %%
abnormal = np.load('abnormalfrequencies1200to1800.pkl.npy')
print(abnormal)
# Out:
# [1502.66792297 1503.82188444 1470.31574121 1470.98263994
#  1471.64984115 1502.67047255 1503.35204658 1504.03392975
#  1504.71612222 1505.3986241  1506.08143555]

# %%
abnormal2 = np.load('abnormalfrequencies900to1300.pkl.npy')
print(abnormal2)
# Out:
# []

# %%
abnormal3 = np.load('abnormalfrequencies1800to2400.pkl.npy')
print(abnormal3)
# Out:
# []
