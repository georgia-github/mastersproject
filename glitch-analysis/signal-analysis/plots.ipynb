# %%
# %matplotlib inline
# %run dataplot
# Out:
# 4194304
# /nfshome/store03/users/georgia.stevens/gwdata/glitchdata/testallinonecode/signalfilter/dataplot.py:51: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#
# /home/georgia.stevens/.conda/envs/ringdown/lib/python3.7/site-packages/gwpy/plot/axes.py:135: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   super().draw(*args, **kwargs)
# /home/georgia.stevens/.conda/envs/ringdown/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
