# %%
# %matplotlib inline
# %run graphs
# Out:
# The highest SNR Values of  7.401520589781671 occurs at a frequency of 1383.6704685625616 Hz

# %%
data = np.load('gwdatatotalfreqs.npy')
print(len(data))
# Out:
# 8441
