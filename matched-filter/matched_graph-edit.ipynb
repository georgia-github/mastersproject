# %%
# %matplotlib inline
# %run test_matched_filter-edit
# Out:
# This data was made from, a frequency range: 1200.0 to 1249.3278403162208 with tau range 0.049999999999999996 to 0.04802582481857863 . It had a maximum optimal SNR value 12.858337188678487 .
