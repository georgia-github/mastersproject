# %%
# %matplotlib inline
# %run test_matched_filter
# Out:
# Signal optimal SNR is 74.6
# Signal optimal SNR is 7.5
# Signal optimal SNR is 0.7

# %%
# %matplotlib inline
# %run test_matched_filter-edit
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /nfshome/store03/users/georgia.stevens/pycbc_edit/test_matched_filter-edit.py in <module>
#      91 fmin = frequencybank[0]
#      92 fmax = frequencybank[-1]
# ---> 93 taumin = taubank[0]
#      94 taumax = taubank[-1]
#      95
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
