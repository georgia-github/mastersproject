# %%
# %matplotlib inline
# %run efficiency
# Out:
# 166
# the 0.1%threshold of 6.62608607288953 has efficiency 0.35078302383419113
# 6.62608607288953
# the 1%threshold of 6.179036890078189 has efficiency 0.2638294848065187
# 0.6352887956339699
